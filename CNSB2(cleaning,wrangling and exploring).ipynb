# %%
import pandas as pd
import missingno as msn

# %%
data1=pd.read_csv('Analyzabledata.csv')

# %%
#data1

# %%
msn.matrix(data1)

# %%
data1.isnull().sum()
# Out:
# PrdAcctId                            0
# Years since opening the account      0
# churn?                               0
# ActTotBalFcy                         0
# CityCd                               0
# PinCode                              0
# Age                                599
# years for cust                     599
# CusType                            599
# MaritalStatus                      599
# ProfCd                             599
# SexCode                            599
# MemberType                         599
# KYCYN                              599
# dtype: int64

# %%
data1['PrdAcctId'].value_counts()
# Out:
# SB    5019
# CA     648
# OD     139
# CC      22
# Name: PrdAcctId, dtype: int64

# %%
#15% data will be dropped if dropna() used

# %%
data1.dropna(inplace=True)

# %%
data1=data1.reset_index(drop=True)

# %%
#data1

# %%
data1 = data1[["PrdAcctId","CityCd","PinCode","CusType","MaritalStatus","SexCode","ProfCd","MemberType","KYCYN","Years since opening the account","years for cust","Age","ActTotBalFcy","churn?"]]

# %%
data1
# Out:
#      PrdAcctId CityCd PinCode  CusType  MaritalStatus SexCode  ProfCd  \
# 0           SB    MUM  400088      2.0            2.0      M     99.0
# 1           SB    MUM  400071      2.0            1.0      M      0.0
# 2           SB    MUM  400089      1.0            2.0      M      0.0
# 3           SB    MUM  400088      1.0            2.0      M     99.0
# 4           SB    MUM  400088      1.0            2.0      M     99.0
# ...        ...    ...     ...      ...            ...     ...     ...
# 5224        SB    NBO  400709      1.0            2.0      M      1.0
# 5225        SB    MUM  400088      1.0            1.0      M      1.0
# 5226        SB    NBO  400701      1.0            1.0      M      1.0
# 5227        SB    MUM  400043     10.0            2.0      M      1.0
# 5228        SB    MUM  400043      1.0            2.0      M      3.0
#
#       MemberType KYCYN  Years since opening the account  years for cust   Age  \
# ...

# %%
#Checking the individual categorical columns

# %%
data1['PrdAcctId'].value_counts()
# Out:
# SB    4994
# CA     145
# OD      81
# CC       9
# Name: PrdAcctId, dtype: int64

# %%
list1=[]
for i in range(len(data1['churn?'])):
    if(data1['churn?'][i]==1):
        list1.append(data1['PrdAcctId'][i])
list1.
# Out:
#   File "<ipython-input-197-c8d6af597373>", line 5
#     list1.
#           ^
# SyntaxError: invalid syntax

# %%
data1['CityCd'].value_counts()
# Out:
# MUM                    3330
# NBO                     944
# NMM                     587
# 1900-04-14 00:00:00     155
# 1901-02-03 00:00:00      72
# THN                      69
# 1900-01-04 00:00:00      22
# IN                       13
# .                         8
# 1900-07-24 00:00:00       7
# PAV                       4
# KLY                       3
# IND                       3
#                           3
# MU                        2
# RAI                       2
# 1900-01-01 00:00:00       1
# 1901-02-16 00:00:00       1
# DMB                       1
# CHB                       1
# 1900-01-03 00:00:00       1
# Name: CityCd, dtype: int64

# %%
"""for i in range(len(data1['CityCd'])):
    if(data1['CityCd'][i]=='1900-04-14 00:00:00' or data1['CityCd'][i]=='1901-02-03 00:00:00' or data1['CityCd'][i]=='1900-01-04 00:00:00' or data1['CityCd'][i]=='.' or data1['CityCd'][i]=='1900-07-24 00:00:00' or data1['CityCd'][i]=='1900-01-01 00:00:00' or data1['CityCd'][i]=='1901-02-16 00:00:00' or data1['CityCd'][i]=='1900-01-03 00:00:00' or data1['CityCd'][i]=='MU ' or data1['CityCd'][i]==data1['CityCd'][2410] or data1['CityCd'][i]==data1['CityCd'][3476]):
        data1['CityCd'][i]='MUM'
""" 
for i in range(len(data1['CityCd'])):
    if(data1['CityCd'][i].isalpha()):
        pass
    else:
        data1['CityCd'][i]='MUM'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data1
# Out:
#      PrdAcctId CityCd PinCode  CusType  MaritalStatus SexCode  ProfCd  \
# 0           SB    MUM  400088      2.0            2.0      M     99.0
# 1           SB    MUM  400071      2.0            1.0      M      0.0
# 2           SB    MUM  400089      1.0            2.0      M      0.0
# 3           SB    MUM  400088      1.0            2.0      M     99.0
# 4           SB    MUM  400088      1.0            2.0      M     99.0
# ...        ...    ...     ...      ...            ...     ...     ...
# 5224        SB    NBO  400709      1.0            2.0      M      1.0
# 5225        SB    MUM  400088      1.0            1.0      M      1.0
# 5226        SB    NBO  400701      1.0            1.0      M      1.0
# 5227        SB    MUM  400043     10.0            2.0      M      1.0
# 5228        SB    MUM  400043      1.0            2.0      M      3.0
#
#       MemberType KYCYN  Years since opening the account  years for cust   Age  \
# ...

# %%
data1.shape
# Out:
# (5229, 14)

# %%
data1['CityCd'].value_counts()
# Out:
# MUM    3615
# NBO     944
# NMM     587
# THN      69
# PAV       4
# IND       3
# KLY       3
# RAI       2
# CHB       1
# DMB       1
# Name: CityCd, dtype: int64

# %%
data1['PinCode'].value_counts()
# Out:
# 400709     2297
# 0          1508
# 400701      266
# 400703      156
# 400705      130
#            ...
# 4000071       1
# 400729        1
# 40705         1
# 400809        1
# 400057        1
# Name: PinCode, Length: 166, dtype: int64

# %%
for i in range(len(data1['PinCode'])):
    if len(data1['PinCode'][i])!=6:
        data1['PinCode'][i]= data1['PinCode'][8]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(data1['PinCode'].value_counts())
# Out:
# 400709    3927
# 400701     266
# 400703     156
# 400705     130
# 400706      75
#           ...
# 400067       1
# 400099       1
# 400729       1
# 400809       1
# 400057       1
# Name: PinCode, Length: 140, dtype: int64

# %%
list1=[]
w=data1['PinCode'].value_counts()
for i in range(len(data1['churn?'])):
    if(data1['churn?'][i]==1):
        list1.append(data1['PinCode'][i])
s=pd.Series(list1)
s.value_counts()
# Out:
# 400709    277
# 400071      7
# 400703      2
# 400701      2
# 400088      2
# 400710      1
# 410209      1
# 400708      1
# 400604      1
# 400043      1
# 400037      1
# 421202      1
# 421301      1
# 400001      1
# 400074      1
# 400027      1
# 400070      1
# 421201      1
# 400003      1
# 400084      1
# 400069      1
# 410206      1
# 400706      1
# dtype: int64

# %%
data1['CusType'].value_counts()
# Out:
# 1.0     4851
# 10.0     183
# 11.0      69
# 2.0       67
# 9.0       25
# 5.0       13
# 12.0       6
# 8.0        4
# 4.0        4
# 0.0        4
# 13.0       3
# Name: CusType, dtype: int64

# %%
data1['MaritalStatus'].value_counts()
# Out:
# 2.0    3921
# 1.0    1288
# 4.0      15
# 0.0       4
# 3.0       1
# Name: MaritalStatus, dtype: int64

# %%
data1['SexCode'].value_counts()
# Out:
# M     4170
# F     1055
#          4
# Name: SexCode, dtype: int64

# %%
for i in range(len(data1['SexCode'])):
    if(data1['SexCode'][i]=='M ' or data1['SexCode'][i]=='F '):
        pass
    else:
        if(i%2==0):
            data1['SexCode'][i]='M '
        else:
            data1['SexCode'][i]='F '
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data1['SexCode'].value_counts()
#data1['SexCode'][746]
# Out:
# M     4173
# F     1056
# Name: SexCode, dtype: int64

# %%
data1['ProfCd'].value_counts()
# Out:
# 0.0     3866
# 1.0      420
# 18.0     245
# 2.0      238
# 3.0      185
# 99.0     131
# 11.0      66
# 9.0       35
# 98.0      34
# 5.0        5
# 12.0       2
# 30.0       1
# 7.0        1
# Name: ProfCd, dtype: int64

# %%
data1['MemberType'].value_counts()
# Out:
# 0.0    3351
# 1.0    1327
# 2.0     551
# Name: MemberType, dtype: int64

# %%
data1['KYCYN'].value_counts()
# Out:
# Y    4370
#       670
# N     189
# Name: KYCYN, dtype: int64

# %%
for i in range(len(data1['KYCYN'])):
    if(data1['KYCYN'][i].isalpha()):
        pass
    else:
        if(i%2==0):
            data1['KYCYN'][i]='Y'
        else:
            data1['KYCYN'][i]='N'
data1['KYCYN'].value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Y    4706
# N     523
# Name: KYCYN, dtype: int64

# %%
#Checking the individual numeric columns

# %%
import seaborn as sns

# %%
sns.distplot(data1['Years since opening the account'])

# %%
sns.distplot(data1['years for cust'])
print(data1['years for cust'].mode())
# Out:
# 0    12.0
# 1    13.0
# dtype: float64

# %%
for i in range(len(data1['years for cust'])):
    if data1['years for cust'][i]>=100:
        data1['years for cust'][i]=data1['Years since opening the account'][0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.distplot(data1['years for cust'])

# %%
sns.distplot(data1['Age'])

# %%
listn=[]
for i in range(len(data1['Age'])):
    if(data1['Age'][i]==120):
        pass
    else:
        listn.append(data1['Age'][i])
n=pd.Series(listn)
    
print(n.mode())
print(n.median())
print(n.std())
#print(data1['Age'].mode())
# Out:
# 0    40.0
# dtype: float64
# 44.0
# 12.730231763102255

# %%
import random 
for i in range(len(data1['Age'])):
    if(data1['Age'][i]==120):
        data1['Age'][i]=random.randint(28,52)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.distplot(data1['Age'])

# %%
sns.distplot(data1['ActTotBalFcy'])

# %%
data1
# Out:
#      PrdAcctId CityCd PinCode  CusType  MaritalStatus SexCode  ProfCd  \
# 0           SB    MUM  400088      2.0            2.0      M     99.0
# 1           SB    MUM  400071      2.0            1.0      M      0.0
# 2           SB    MUM  400089      1.0            2.0      M      0.0
# 3           SB    MUM  400088      1.0            2.0      M     99.0
# 4           SB    MUM  400088      1.0            2.0      M     99.0
# ...        ...    ...     ...      ...            ...     ...     ...
# 5224        SB    NBO  400709      1.0            2.0      M      1.0
# 5225        SB    MUM  400088      1.0            1.0      M      1.0
# 5226        SB    NBO  400701      1.0            1.0      M      1.0
# 5227        SB    MUM  400043     10.0            2.0      M      1.0
# 5228        SB    MUM  400043      1.0            2.0      M      3.0
#
#       MemberType KYCYN  Years since opening the account  years for cust   Age  \
# ...

# %%
data1['churn?'].value_counts()
# Out:
# 0    4921
# 1     308
# Name: churn?, dtype: int64

# %%
data1['PrdAcctId'].value_counts()
# Out:
# SB    4994
# CA     145
# OD      81
# CC       9
# Name: PrdAcctId, dtype: int64

# %%
data1['CityCd'].value_counts()
# Out:
# MUM    3615
# NBO     944
# NMM     587
# THN      69
# PAV       4
# IND       3
# KLY       3
# RAI       2
# CHB       1
# DMB       1
# Name: CityCd, dtype: int64

# %%
data1['PinCode'].value_counts()
# Out:
# 400709    3927
# 400701     266
# 400703     156
# 400705     130
# 400706      75
#           ...
# 400067       1
# 400099       1
# 400729       1
# 400809       1
# 400057       1
# Name: PinCode, Length: 140, dtype: int64

# %%
data1['CusType'].value_counts()
# Out:
# 1.0     4851
# 10.0     183
# 11.0      69
# 2.0       67
# 9.0       25
# 5.0       13
# 12.0       6
# 8.0        4
# 4.0        4
# 0.0        4
# 13.0       3
# Name: CusType, dtype: int64

# %%
data1['MaritalStatus'].value_counts()
# Out:
# 2.0    3921
# 1.0    1288
# 4.0      15
# 0.0       4
# 3.0       1
# Name: MaritalStatus, dtype: int64

# %%
data1['SexCode'].value_counts()
# Out:
# M     4173
# F     1056
# Name: SexCode, dtype: int64

# %%
data1['ProfCd'].value_counts()
# Out:
# 0.0     3866
# 1.0      420
# 18.0     245
# 2.0      238
# 3.0      185
# 99.0     131
# 11.0      66
# 9.0       35
# 98.0      34
# 5.0        5
# 12.0       2
# 30.0       1
# 7.0        1
# Name: ProfCd, dtype: int64

# %%
data1['MemberType'].value_counts()
# Out:
# 0.0    3351
# 1.0    1327
# 2.0     551
# Name: MemberType, dtype: int64

# %%
data1['KYCYN'].value_counts()
# Out:
# Y    4706
# N     523
# Name: KYCYN, dtype: int64

# %%
sns.distplot(data1['Years since opening the account'])

# %%
sns.distplot(data1['years for cust'])

# %%
sns.distplot(data1['Age'])

# %%
sns.distplot(data1['ActTotBalFcy'])

# %%
data1.to_csv('C:/Users/Saurabh Khanolkar/Desktop/wrangleddata.csv', index=False)
